# %% [markdown]
# # **AI: Generative Artificial Intelligence**
#
# **Resources**:
# - ai.cs50.dev?
#
# **Applications of AI**
# - Spam Filtering
# - Watch Recommendations
# - Voice Assistants
# - Code Assistants
# - ...

# %% [markdown]
# ## **Prompts**
# - **System prompt**: nudges underlining AI to have a specific personality or expertise.
# - **User prompt**:

# %% [markdown]
# ## **Machine Learning**

# %% [markdown]
# **Manual(hard-coded) Problem-Solving Algorithms**
# - Decision Trees
# - **Minimax**: choosing the minimum value for maximum results. Used in programs like `tic-tac-toe`.
#
# **Automated Problem-Solving Algorithms - ML**
# With AI, thanks to Machine learning, problems that are generally hard to solve with hard-coded instructions or algorithms, can be solved more deterministically, by letting the AI make decisions in response to dynamic.
#
# **Explore vs. Exploit**:

# %% [markdown]
# ### **ML Techniques**
# [1] **Supervised Learning**
# [2] **Unsupervised Learning**
# Both above involves human in the loop
#
#
# [3] **Deep learning** (no human in the loop process) using **Neural Networks (inspired by biology)** where the model or program learns for itself how to solve a problem.
#
# Example of a "neural" function:
# $$f(x,y) = ax+by+c > 0$$
# $a,b,c$ = parameters
# $x,y$ =
#
# **Eg of neural networks**:
# - GPT: Generative Pre-trained Transformer
#
# **LLMS** (Large Language Models) are statistical models. One problems they posses is Hallucinations.

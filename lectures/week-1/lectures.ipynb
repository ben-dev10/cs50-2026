// %%
#include <stdio.h>

int main(void){
    int scores[3];
    scores[0] = 72;
    scores[1] = 73;
    scores[2] = 33;

    printf("Average: %f \n", (scores[0] + scores[1] + scores[2]) / 3.0);
}
// Out:
// Average: 59.333333

// %%
#include <cs50.h>
#include <stdio.h>

void print_row(int spaces, int bricks);

int main(void)
{
    int h;
    do
    {
        // height of pyramid
        h = get_int("Height: ");
    } while (h < 1 || h > 8);

    // print cols and rows
    for (int col = 0; col < h; col++)
    {
        print_row(h - col, col + 1);
    }
}

void print_row(int spaces, int bricks)
{

    // print spaces
    for (int s = 0; s < spaces - 1; s++)
    {
        printf("-");
    }

    // print brick row
    for (int row = 0; row < bricks; row++)
    {
        printf("#");
    }
    printf("\n");
}
// Out:
// /tmp/tmphnckb945.out: symbol lookup error: /tmp/tmplnlnsk29.out: undefined symbol: get_int
// [C kernel] Executable exited with code 127

// %%
#include <stdio.h>

int main(void){
    printf("Hello World");
}
// Out:
// Hello World

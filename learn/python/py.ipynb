# %% [markdown]
# # **Python**

# %%
print("Hello World from Python!")
# Out:
# Hello World from Python!

# %% [markdown]
# #### **Facts**
# - Python doesn't have a native `do-while` loop

# %%
True and False
# Out:
# False

# %%
# An empty dictionary is equal to dict

if {} == dict:
    print(True)
else:
    print(False)

{} == dict  # in assignment, use dict()
# Out:
# True
# True
